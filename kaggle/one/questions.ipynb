# %% [markdown]
# I'll break down each task with more detailed explanations and specific questions to answer:
#
# ## Data Cleaning Tasks
#
# ### 1. **Basic Data Exploration**
# **What you need to do:**
# - **Load the data:** Read the CSV file into a pandas DataFrame
# - **Check the structure:**
#   - How many rows and columns does the dataset have?
#   - What are the column names?
#   - What data type is each column (integer, float, object/string)?
# - **Preview the data:**
#   - What do the first 5 rows look like?
#   - What do the last 5 rows look like?
# - **Get basic statistics:**
#   - What's the average age of students?
#   - What's the minimum and maximum daily usage hours?
#   - What's the mean mental health score?
#
# ### 2. **Missing Data Investigation**
# **What you need to do:**
# - **Count missing values:** Are there any empty cells (NaN values) in any column?
# - **Calculate percentages:** What percentage of data is missing in each column?
# - **Decide what to do:** Should you delete rows with missing data or fill them with something?
#
# ### 3. **Data Type Corrections**
# **What you need to do:**
# - **Check current types:** Is "Age" stored as a number or text?
# - **Fix if needed:** Convert text numbers to actual numbers
# - **Example issues to look for:**
#   - Are usage hours stored as decimals (float) or whole numbers (int)?
#   - Are Yes/No columns stored properly?
#
# ### 4. **Duplicate Detection**
# **What you need to do:**
# - **Check Student IDs:** Does any student appear twice in the dataset?
# - **Check entire rows:** Are there any completely identical rows?
# - **Remove duplicates:** Keep only one copy of each student
#
# ### 5. **Data Validation**
# **What you need to do:**
# - **Check for impossible values:**
#   - Are there students with negative ages?
#   - Does anyone use social media more than 24 hours per day?
#   - Does anyone sleep more than 24 hours or negative hours?
#   - Are Mental Health Scores between reasonable limits (like 1-10)?
# - **Fix or flag these errors**
#
# ## Data Analysis Tasks
#
# ### 6. **Descriptive Statistics**
# **Specific questions to answer:**
# - What's the average age of students in the study?
# - What's the most common daily usage hours?
# - How many students are male vs female?
# - What's the average mental health score?
# - Which values appear most often in each column?
#
# ### 7. **Platform Analysis**
# **Specific questions to answer:**
# - Which social media platform is used by the most students?
# - How many students use Instagram vs TikTok vs Facebook?
# - Do students from certain countries prefer specific platforms?
# - Do male and female students prefer different platforms?
# - What percentage of students use each platform?
#
# ### 8. **Usage Patterns**
# **Specific questions to answer:**
# - Do undergraduate students use social media more than graduate students?
# - Who uses social media more - males or females?
# - Do older students use social media less than younger students?
# - What's the average usage for 18-year-olds vs 24-year-olds?
#
# ### 9. **Academic Impact Analysis**
# **Specific questions to answer:**
# - How many students say social media affects their academic performance?
# - What percentage of all students report academic impact?
# - Do students who report academic impact actually use social media more hours?
# - What's the average usage hours for students who say "Yes" vs "No" to academic impact?
#
# ### 10. **Sleep and Mental Health Correlations**
# **Specific questions to answer:**
# - Do students who use social media more sleep less?
# - What's the average mental health score for students who sleep 8+ hours vs less than 6 hours?
# - Do students with higher social media usage have lower mental health scores?
# - Group students by sleep ranges (0-5 hours, 6-7 hours, 8+ hours) and compare their other metrics
#
# ### 11. **Country-wise Analysis**
# **Specific questions to answer:**
# - Which countries have the most students in this study?
# - Do students from certain countries use social media more than others?
# - What's the average daily usage in USA vs India vs Bangladesh?
# - Which country has the highest addiction scores on average?
# - Are there regional patterns (like Asian countries vs European countries)?
#
# ### 12. **Relationship Status Insights**
# **Specific questions to answer:**
# - How many students are single vs in relationships vs complicated?
# - Do students in relationships use social media differently than single students?
# - Who reports more conflicts over social media - people in relationships or single people?
# - What's the average addiction score for each relationship status?
#
# ## Bonus Challenges
#
# ### 13. **Create New Variables**
# **What you need to do:**
# - **Usage Categories:**
#   - Create a new column that labels students as:
#     - "Light User" (0-3 hours/day)
#     - "Moderate User" (3-6 hours/day)
#     - "Heavy User" (6+ hours/day)
# - **Age Groups:**
#   - Create categories like "Teens" (18-19), "Early 20s" (20-22), "Mid 20s" (23-24)
# - **Risk Score:**
#   - Combine high usage + low sleep + low mental health score to create a "risk" category
#
# ### 14. **Data Quality Report**
# **What you need to do:**
# - **Document problems found:** Make a list of all the data issues you discovered
# - **Count the problems:** How many students had impossible values?
# - **Suggest fixes:** What should be done to improve this dataset?
#
# **Example specific questions for each task:**
# - Task 6: "What is the exact average daily usage hours across all students?"
# - Task 7: "How many students use Instagram as their most-used platform?"
# - Task 8: "What's the difference in average usage hours between male and female students?"
# - Task 9: "Of the students who say social media affects their academics, what's their average daily usage?"
#
# Each task should result in specific numbers, charts, or insights that you can clearly state and explain!
