# %% [markdown]
# ### Squares, Cubes, and Fraction to Percentage Table
#
# | Square (n²)       | Cube (n³)      |
# |------------       |-----------     |
# | 1²  = 1           | 1³  = 1        |
# | 2²  = 4           | 2³  = 8        |
# | 3²  = 9           | 3³  = 27       |
# | 4²  = 16          | 4³  = 64       |
# | 5²  = 25          | 5³  = 125      |
# | 6²  = 36          | 6³  = 216      |
# | 7²  = 49          | 7³  = 343      |
# | 8²  = 64          | 8³  = 512      |
# | 9²  = 81          | 9³  = 729      |
# | 10² = 100         | 10³ = 1000     |
# | 11² = 121         | 11³ = 1331     |
# | 12² = 144         | 12³ = 1728     |
# | 13² = 169         | 13³ = 2197     |
# | 14² = 196         | 14³ = 2744     |
# | 15² = 225         | 15³ = 3375     |
# | 16² = 256         | 16³ = 4096     |
# | 17² = 289         | 17³ = 4913     |
# | 18² = 324         | 18³ = 5832     |
# | 19² = 361         | 19³ = 6859     |
# | 20² = 400         | 20³ = 8000     |
# | 21² = 441         | 21³ = 9261     |
# | 22² = 484         | 22³ = 10648    |
# | 23² = 529         | 23³ = 12167    |
# | 24² = 576         | 24³ = 13824    |
# | 25² = 625         | 25³ = 15625    |
# | 26² = 676         | 26³ = 17576    |
# | 27² = 729         | 27³ = 19683    |
# | 28² = 784         | 28³ = 21952    |
# | 29² = 841         | 29³ = 24389    |
# | 30² = 900         | 30³ = 27000    |
# | 31² = 961         |                |
# | 32² = 1024        |                |
# | 33² = 1089        |                |
# | 34² = 1156        |                |
# | 35² = 1225        |                |
# | 36² = 1296        |                |
# | 37² = 1369        |                |
# | 38² = 1444        |                |
# | 39² = 1521        |                |
# | 40² = 1600        |                |
# | 41² = 1681        |                |
# | 42² = 1764        |                |
# | 43² = 1849        |                |
# | 44² = 1936        |                |
# | 45² = 2025        |                |
# | 46² = 2116        |                |
# | 47² = 2209        |                |
# | 48² = 2304        |                |
# | 49² = 2401        |                |
# | 50² = 2500        |                |
#
#
#  # fraction to percentage
# | Fraction | Percentage |
# |----------|------------|
# | 1/2      | 50%        |
# | 1/3      | 33.33%     |
# | 1/4      | 25%        |
# | 1/5      | 20%        |
# | 1/6      | 16.66%     |
# | 1/7      | 14.28%     |
# | 1/8      | 12.50%     |
# | 1/9      | 11.11%     |
# | 1/10     | 10%        |
# | 1/11     | 9.09%      |
# | 1/12     | 8.33%      |
# | 1/13     | 7.69%      |
# | 1/14     | 7.14%      |
# | 1/15     | 6.66%      |
# | 1/16     | 6.25%      |
# | 1/17     | 5.88%      |
# | 1/18     | 5.55%      |
# | 1/19     | 5.26%      |
# | 1/20     | 5%         |
# | 2/3      | 66.66%     |
# | 3/4      | 75%        |
# | 4/5      | 80%        |
# | 5/8      | 62.5%      |
# | 3/5      | 60%        |
# | 7/12     | 58.33%     |
# | 9/16     | 56.25%     |
# | 5/11     | 45.45%     |
# | 7/16     | 43.75%     |
# | 5/12     | 41.66%     |
# | 3/8      | 37.5%      |
# | 5/16     | 31.25%     |
# | 3/10     | 30%        |
